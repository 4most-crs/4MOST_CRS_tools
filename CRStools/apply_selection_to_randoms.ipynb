# %%
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp
import sys
import utils

# %%
random_path = '/its/home/bb345/5-4most_data/CRS/random_catalogues/LS_randoms/dr10_randoms/randoms-1-0.fits'

# %%
random = Table.read(random_path)

# %%
hpmap = utils.create_hp_map(random['RA'], random['DEC'], nside=128)
utils.plot_moll(hpmap, rot=115, min=30, max=100, fourmost_footprint=True)
# Out:
# /its/home/bb345/.conda/envs/clustering-3.12/lib/python3.12/site-packages/healpy/visufunc.py:764: UserWarning: Ignoring specified arguments in this call because figure with num: 1 already exists
#   f = pylab.figure(fig, figsize=(8.5, 5.4))

# %%
nobs_mask = (random['NOBS_G'] > 0) & (random['NOBS_R'] > 0) & (random['NOBS_Z'] > 0)

# %%
random = random[nobs_mask]

# %%
hpmap = utils.create_hp_map(random['RA'][nobs_mask], random['DEC'][nobs_mask], nside=128)
utils.plot_moll(hpmap, rot=115, min=30, max=100, fourmost_footprint=True)
# Out:
# /its/home/bb345/.conda/envs/clustering-3.12/lib/python3.12/site-packages/healpy/visufunc.py:764: UserWarning: Ignoring specified arguments in this call because figure with num: 1 already exists
#   f = pylab.figure(fig, figsize=(8.5, 5.4))

# %%
mask_s8fp_LRG = utils.get_4most_s8foot(random['RA'], random['DEC'], bg_fp=False)
mask_s8fp_BG = utils.get_4most_s8foot(random['RA'], random['DEC'], bg_fp=True)

# %%
mask_s8fp_LRG &= nobs_mask
mask_s8fp_BG &= nobs_mask

# %%
hpmap = utils.create_hp_map(random['RA'][mask_s8fp_LRG], random['DEC'][mask_s8fp_LRG], nside=128)
utils.plot_moll(hpmap, rot=115, min=1000, max=3000, fourmost_footprint=True)
# Out:
# /its/home/bb345/.conda/envs/clustering-3.12/lib/python3.12/site-packages/healpy/visufunc.py:764: UserWarning: Ignoring specified arguments in this call because figure with num: 1 already exists
#   f = pylab.figure(fig, figsize=(8.5, 5.4))

# %%
hpmap = utils.create_hp_map(random['RA'][mask_s8fp_BG], random['DEC'][mask_s8fp_BG], nside=128)
utils.plot_moll(hpmap, rot=115, min=1000, max=3000, fourmost_footprint=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 hpmap = utils.create_hp_map(random['RA'][mask_s8fp_BG], random['DEC'][mask_s8fp_BG], nside=128)
#       2 utils.plot_moll(hpmap, rot=115, min=1000, max=3000, fourmost_footprint=True)
#
# NameError: name 'random' is not defined

# %%
mask = np.ones(len(data), dtype=bool)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 mask = np.ones(len(data), dtype=bool)
#
# NameError: name 'np' is not defined
